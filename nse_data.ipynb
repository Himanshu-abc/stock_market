# %% [markdown]
# <a href="https://colab.research.google.com/github/Himanshu-abc/stock_market/blob/main/nse_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nselib

# %%
import nselib

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 16  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 17  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 18  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 19  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 20  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                            description Sr_no
# 0                      Special Holiday     1
# 1                         Republic Day     2
# ...

# %%
from nselib import capital_market

# %%
capital_market.bhav_copy_equities('29-08-2024')
# Out:
#           TradDt       BizDt Sgmt  Src FinInstrmTp  FinInstrmId          ISIN  \
# 0     2024-08-29  2024-08-29   CM  NSE         STK        18341  INE0AE001013
# 1     2024-08-29  2024-08-29   CM  NSE         STK        11571  INE0DK501011
# 2     2024-08-29  2024-08-29   CM  NSE         STK        23721  INE0TNX01015
# 3     2024-08-29  2024-08-29   CM  NSE         STK        19456  IN0020230093
# 4     2024-08-29  2024-08-29   CM  NSE         STK          368  INE373A01013
# ...          ...         ...  ...  ...         ...          ...           ...
# 2816  2024-08-29  2024-08-29   CM  NSE         STK        15184  INE791I01019
# 2817  2024-08-29  2024-08-29   CM  NSE         STK          595  INE120A01034
# 2818  2024-08-29  2024-08-29   CM  NSE         STK         6531  INE0H7R23014
# 2819  2024-08-29  2024-08-29   CM  NSE         STK          956  IN0020200252
# 2820  2024-08-29  2024-08-29   CM  NSE         STK         9116  INE760F01028
#
# ...

# %%
capital_market.bhav_copy_with_delivery("29-08-2024")
# Out:
#           SYMBOL SERIES        DATE1  PREV_CLOSE  OPEN_PRICE  HIGH_PRICE  \
# 0     1018GS2026     GS  29-Aug-2024      120.00      119.90      120.00
# 1      20MICRONS     EQ  29-Aug-2024      324.00      325.25      330.50
# 2     21STCENMGM     BE  29-Aug-2024      116.03      113.70      118.35
# 3         360ONE     EQ  29-Aug-2024     1097.45     1097.90     1107.55
# 4      3IINFOLTD     EQ  29-Aug-2024       36.29       36.39       36.44
# ...          ...    ...          ...         ...         ...         ...
# 2654       ZTECH     SM  29-Aug-2024      334.70      327.10      345.10
# 2655       ZUARI     EQ  29-Aug-2024      206.05      206.70      208.80
# 2656    ZUARIIND     EQ  29-Aug-2024      378.65      379.60      381.90
# 2657   ZYDUSLIFE     EQ  29-Aug-2024     1138.30     1138.30     1144.60
# 2658   ZYDUSWELL     EQ  29-Aug-2024     2289.20     2314.45     2317.95
#
#       LOW_PRICE  LAST_PRICE  CLOSE_PRICE  AVG_PRICE  TTL_TRD_QNTY  \
# ...

# %%
capital_market.block_deals_data(from_date='1-1-2004', to_date='1-1-2006')
# Out:
# /usr/local/lib/python3.10/dist-packages/nselib/capital_market/capital_market_data.py:335: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#             Date      Symbol             SecurityName  \
# 0    17-NOV-2005        GHCL             GHCL LIMITED
# 1    17-NOV-2005        GHCL             GHCL LIMITED
# 2    23-NOV-2005  PUNJABTRAC      PUNJAB TRACTORS LTD
# 3    23-NOV-2005  PUNJABTRAC      PUNJAB TRACTORS LTD
# 4    29-NOV-2005       MICRO           MICRO INKS LTD
# ..           ...         ...                      ...
# 141  30-DEC-2005    RELIANCE  RELIANCE INDUSTRIES LTD
# 142  30-DEC-2005    RELIANCE  RELIANCE INDUSTRIES LTD
# ...

# %%
capital_market.block_deals_data(period='1M')
# Out:
#             Date      Symbol              SecurityName  \
# 0    29-JUL-2024    INDHOTEL    Indian Hotels Co. Ltd.
# 1    29-JUL-2024    INDHOTEL    Indian Hotels Co. Ltd.
# 2    29-JUL-2024    JYOTICNC  Jyoti CNC Automation Ltd
# 3    29-JUL-2024    JYOTICNC  Jyoti CNC Automation Ltd
# 4    29-JUL-2024    JYOTICNC  Jyoti CNC Automation Ltd
# ..           ...         ...                       ...
# 205  29-AUG-2024  WELSPUNLIV    Welspun Living Limited
# 206  29-AUG-2024  WELSPUNLIV    Welspun Living Limited
# 207  29-AUG-2024  WELSPUNLIV    Welspun Living Limited
# 208  29-AUG-2024  WELSPUNLIV    Welspun Living Limited
# 209  29-AUG-2024  WELSPUNLIV    Welspun Living Limited
#
#                          ClientName Buy/Sell QuantityTraded  \
# 0           DODONA HOLDINGS LIMITED     SELL       3,21,741
# 1                    SIDDHARTHA YOG      BUY       3,21,741
# 2       ASTORNE CAPITAL VCC   ARVEN      BUY         89,048
# ...

# %%
capital_market.bulk_deal_data(from_date='1-1-2004', to_date='31-12-2004')
# Out:
#              Date      Symbol  \
# 0     04-JAN-2004   AUTOAXLES
# 1     04-JAN-2004      D-LINK
# 2     04-JAN-2004    INDIACEM
# 3     04-JAN-2004   MAARSOFTW
# 4     04-JAN-2004     MID-DAY
# ...           ...         ...
# 1148  31-DEC-2004        IT&T
# 1149  31-DEC-2004    POLYPLEX
# 1150  31-DEC-2004    POLYPLEX
# 1151  31-DEC-2004  SALORAINTL
# 1152  31-DEC-2004  SRIADIKARI
#
#                                           SecurityName  \
# 0                                 AUTOMATIVE AXLES LTD
# 1                                 D-LINK INDIA LIMITED
# 2                                    INDIA CEMENTS LTD
# 3                              MAARS SOFTWARE INTERNAT
# 4                               MID-DAY MULTIMEDIA LTD
# ...                                                ...
# 1148                                          IT&T LTD
# 1149                          POLYPLEX CORPORATION LTD
# 1150                          POLYPLEX CORPORATION LTD
# ...

# %% [markdown]
# Stock specific information

# %%
capital_market.deliverable_position_data('SBIN',period='1Y')
# Out:
#     Symbol Series         Date    TradedQty DeliverableQty  %DlyQttoTradedQty
# 0     SBIN     EQ  29-Aug-2023  1,31,44,855      42,70,158              32.49
# 1     SBIN     EQ  30-Aug-2023  1,52,81,416      67,48,751              44.16
# 2     SBIN     EQ  31-Aug-2023  2,78,98,476    1,04,48,308              37.45
# 3     SBIN     EQ  01-Sep-2023  1,81,21,168      78,28,067              43.20
# 4     SBIN     EQ  04-Sep-2023  1,21,08,655      48,50,266              40.06
# ..     ...    ...          ...          ...            ...                ...
# 251   SBIN     EQ  23-Aug-2024    55,37,747      23,03,827              41.60
# 252   SBIN     EQ  26-Aug-2024    85,23,795      38,45,255              45.11
# 253   SBIN     EQ  27-Aug-2024  1,28,33,290      54,96,803              42.83
# 254   SBIN     EQ  28-Aug-2024  1,03,71,300      49,67,658              47.90
# 255   SBIN     EQ  29-Aug-2024  1,82,47,268    1,08,75,917              59.60
#
# [256 rows x 6 columns]

# %%
capital_market.deliverable_position_data('SBIN',from_date='1-1-1993', to_date='1-1-2005')
# Out:
#     Symbol Series         Date  TradedQty DeliverableQty  %DlyQttoTradedQty
# 0     SBIN     EQ  12-Feb-2002  13,49,150       3,27,484              24.27
# 1     SBIN     EQ  13-Feb-2002  32,06,936       7,69,487              23.99
# 2     SBIN     EQ  14-Feb-2002  43,12,103      11,14,574              25.85
# 3     SBIN     EQ  15-Feb-2002  18,53,235       4,44,832              24.00
# 4     SBIN     EQ  18-Feb-2002  19,05,105       4,29,331              22.54
# ..     ...    ...          ...        ...            ...                ...
# 718   SBIN     EQ  27-Dec-2004  22,00,440       1,39,718               6.35
# 719   SBIN     EQ  28-Dec-2004  27,58,878       3,08,723              11.19
# 720   SBIN     EQ  29-Dec-2004  19,65,922       2,49,955              12.71
# 721   SBIN     EQ  30-Dec-2004  40,51,527       5,80,050              14.32
# 722   SBIN     EQ  31-Dec-2004  34,47,160       6,36,227              18.46
#
# [723 rows x 6 columns]

# %% [markdown]
# stock specific information with volume

# %%
capital_market.price_volume_and_deliverable_position_data('SBIN',period='1Y')
# Out:
# /usr/local/lib/python3.10/dist-packages/nselib/capital_market/capital_market_data.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#     Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0      NaN     EQ  29-Aug-2023     572.85     573.65     576.30    571.85
# 1      NaN     EQ  30-Aug-2023     574.85     576.70     577.70    566.10
# 2      NaN     EQ  31-Aug-2023     567.40     569.30     570.30    559.40
# 3      NaN     EQ  01-Sep-2023     561.35     562.70     571.20    562.10
# 4      NaN     EQ  04-Sep-2023     569.55     572.00     576.35    568.45
# ..     ...    ...          ...        ...        ...        ...       ...
# ...

# %%
capital_market.price_volume_and_deliverable_position_data('SBIN',from_date='1-1-1993', to_date='1-1-2005')
# Out:
# /usr/local/lib/python3.10/dist-packages/nselib/capital_market/capital_market_data.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#      Symbol Series         Date PrevClose OpenPrice HighPrice LowPrice  \
# 0       NaN     EQ  01-Jan-1996    198.10     198.1    201.15    196.5
# 1       NaN     EQ  02-Jan-1996    199.50    200.25     201.0    188.0
# 2       NaN     EQ  03-Jan-1996    193.15    194.25     196.8    187.0
# 3       NaN     EQ  04-Jan-1996    188.00     185.5     189.0   182.55
# 4       NaN     EQ  05-Jan-1996    187.35     188.0     188.5   185.05
# ...     ...    ...          ...       ...       ...       ...      ...
# ...

# %%
capital_market.price_volume_data('SBIN', period='1M')
# Out:
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0    SBIN     EQ  29-Jul-2024     862.45     866.05     889.10    863.20
# 1    SBIN     EQ  30-Jul-2024     871.60     874.70     880.55    869.00
# 2    SBIN     EQ  31-Jul-2024     872.80     873.85     874.95    868.00
# 3    SBIN     EQ  01-Aug-2024     872.40     877.80     881.40    859.45
# 4    SBIN     EQ  02-Aug-2024     862.65     856.70     858.30    846.15
# 5    SBIN     EQ  05-Aug-2024     847.85     830.00     831.35    800.00
# 6    SBIN     EQ  06-Aug-2024     811.65     822.65     826.55    795.65
# 7    SBIN     EQ  07-Aug-2024     797.70     809.00     810.70    800.55
# 8    SBIN     EQ  08-Aug-2024     808.65     812.00     817.80    802.80
# 9    SBIN     EQ  09-Aug-2024     808.05     816.00     829.95    809.55
# 10   SBIN     EQ  12-Aug-2024     824.30     820.60     823.00    811.20
# 11   SBIN     EQ  13-Aug-2024     812.60     813.50     820.00    795.05
# ...

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1990        ZOTA                  Zota Health Care LImited      EQ
# 1991       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1992    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1993   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1994   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
capital_market.fno_equity_list()
# Out:
#                         underlying      symbol  serialNumber
# 0                ABB India Limited         ABB             1
# 1                      ACC Limited         ACC             2
# 2    AU Small Finance Bank Limited      AUBANK             3
# 3         Aarti Industries Limited    AARTIIND             4
# 4             Abbott India Limited  ABBOTINDIA             5
# ..                             ...         ...           ...
# 175                Vedanta Limited        VEDL           176
# 176          Vodafone Idea Limited        IDEA           177
# 177                 Voltas Limited      VOLTAS           178
# 178                  Wipro Limited       WIPRO           179
# 179     Zydus Lifesciences Limited   ZYDUSLIFE           180
#
# [180 rows x 3 columns]

# %% [markdown]
# GET THE INDEX DATA

# %%
capital_market.index_data('NIFTY 50', period='1M')
# Out:
#      TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  HIGH_INDEX_VAL  CLOSE_INDEX_VAL  \
# 0   29-07-2024   NIFTY 50        24943.30        24999.75         24836.10
# 1   30-07-2024   NIFTY 50        24839.40        24971.75         24857.30
# 2   31-07-2024   NIFTY 50        24886.70        24984.60         24951.15
# 3   01-08-2024   NIFTY 50        25030.95        25078.30         25010.90
# 4   02-08-2024   NIFTY 50        24789.00        24851.90         24717.70
# 5   05-08-2024   NIFTY 50        24302.85        24350.05         24055.60
# 6   06-08-2024   NIFTY 50        24189.85        24382.60         23992.55
# 7   07-08-2024   NIFTY 50        24289.40        24337.70         24297.50
# 8   08-08-2024   NIFTY 50        24248.55        24340.50         24117.00
# 9   09-08-2024   NIFTY 50        24386.85        24419.75         24367.50
# 10  12-08-2024   NIFTY 50        24320.05        24472.80         24347.00
# ...

# %%
capital_market.index_data('NIFTY METAL', period='1M')
# Out:
#      TIMESTAMP   INDEX_NAME  OPEN_INDEX_VAL  HIGH_INDEX_VAL  CLOSE_INDEX_VAL  \
# 0   29-07-2024  NIFTY METAL         9510.75         9520.35          9450.30
# 1   30-07-2024  NIFTY METAL         9441.55         9512.45          9468.35
# 2   31-07-2024  NIFTY METAL         9550.75         9611.10          9583.40
# 3   01-08-2024  NIFTY METAL         9690.85         9759.60          9573.20
# 4   02-08-2024  NIFTY METAL         9440.35         9448.30          9314.55
# 5   05-08-2024  NIFTY METAL         9077.20         9100.05          8862.50
# 6   06-08-2024  NIFTY METAL         8955.55         9086.65          8888.95
# 7   07-08-2024  NIFTY METAL         9064.25         9152.05          9128.45
# 8   08-08-2024  NIFTY METAL         9115.00         9115.80          8969.25
# 9   09-08-2024  NIFTY METAL         9086.75         9099.05          9038.30
# 10  12-08-2024  NIFTY METAL         8970.20         9149.30          9106.25
# ...

# %% [markdown]
# GET ALL THE INDEX DATA

# %%
capital_market.market_watch_all_indices()
# Out:
#                      key                                      index  \
# 0   BROAD MARKET INDICES                                   NIFTY 50
# 1   BROAD MARKET INDICES                              NIFTY NEXT 50
# 2   BROAD MARKET INDICES                                  NIFTY 100
# 3   BROAD MARKET INDICES                                  NIFTY 200
# 4   BROAD MARKET INDICES                                  NIFTY 500
# ..                   ...                                        ...
# 72  FIXED INCOME INDICES  NIFTY 10 YR BENCHMARK G-SEC (CLEAN PRICE)
# 73  FIXED INCOME INDICES                   NIFTY 4-8 YR G-SEC INDEX
# 74  FIXED INCOME INDICES                 NIFTY 11-15 YR G-SEC INDEX
# 75  FIXED INCOME INDICES          NIFTY 15 YR AND ABOVE G-SEC INDEX
# 76  FIXED INCOME INDICES                NIFTY COMPOSITE G-SEC INDEX
#
#           indexSymbol      last  variation  percentChange      open      high  \
# ...

# %%
capital_market.nifty50_equity_list()
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8            Bharat Petroleum Corporation Ltd.
# 9                           Bharti Airtel Ltd.
# 10                   Britannia Industries Ltd.
# 11                                  Cipla Ltd.
# 12                             Coal India Ltd.
# 13                    Divi's Laboratories Ltd.
# 14               Dr. Reddy's Laboratories Ltd.
# 15                          Eicher Motors Ltd.
# 16                      Grasim Industries Ltd.
# 17                       HCL Technologies Ltd.
# 18                              HDFC Bank Ltd.
# ...

# %%
capital_market.short_selling_data(period='1D')
# Out:
#            Date      Symbol               SecurityName Quantity
# 0   27-Aug-2024     YESBANK           YES BANK LIMITED        1
# 1   27-Aug-2024    RELIANCE    RELIANCE INDUSTRIES LTD        5
# 2   27-Aug-2024      RECLTD      RURAL ELEC CORP. LTD.      100
# 3   27-Aug-2024      VOLTAS                 VOLTAS LTD   36,000
# 4   27-Aug-2024  DATAMATICS  DATAMATICS GLOBAL SER LTD   10,140
# 5   27-Aug-2024        IDEA      IDEA CELLULAR LIMITED        1
# 6   28-Aug-2024   EICHERMOT      EICHER MOTORS LIMITED   64,925
# 7   28-Aug-2024  OBEROIRLTY      OBEROI REALTY LIMITED       24
# 8   28-Aug-2024       UFLEX              UFLEX LIMITED      247
# 9   28-Aug-2024   SOUTHBANK  THE SOUTH INDIAN BANK LTD        1
# 10  28-Aug-2024        NHPC                   NHPC LTD      400
# 11  28-Aug-2024       PIIND  PI INDUSTRIES LTD               22
# 12  28-Aug-2024  DATAMATICS  DATAMATICS GLOBAL SER LTD    2,450

# %%
from nselib import derivatives

# %%
derivatives.expiry_dates_future()
# Out:
# ['29-Aug-2024', '26-Sep-2024', '31-Oct-2024']

# %%
derivatives.expiry_dates_option_index()
# Out:
# {'NIFTY': ['29-Aug-2024',
#   '05-Sep-2024',
#   '12-Sep-2024',
#   '19-Sep-2024',
#   '26-Sep-2024',
#   '03-Oct-2024',
#   '31-Oct-2024',
#   '26-Dec-2024',
#   '27-Mar-2025',
#   '26-Jun-2025',
#   '24-Dec-2025',
#   '25-Jun-2026',
#   '31-Dec-2026',
#   '24-Jun-2027',
#   '30-Dec-2027',
#   '29-Jun-2028',
#   '28-Dec-2028',
#   '28-Jun-2029'],
#  'FINNIFTY': ['03-Sep-2024',
#   '10-Sep-2024',
#   '17-Sep-2024',
#   '24-Sep-2024',
#   '01-Oct-2024',
#   '29-Oct-2024',
#   '26-Nov-2024'],
#  'BANKNIFTY': ['04-Sep-2024',
#   '11-Sep-2024',
#   '18-Sep-2024',
#   '25-Sep-2024',
#   '01-Oct-2024',
#   '30-Oct-2024',
#   '27-Nov-2024',
#   '24-Dec-2024',
#   '26-Mar-2025',
#   '25-Jun-2025']}

# %%
derivatives.fii_derivatives_statistics('28-08-2024')
# Out:
#        fii_derivatives  buy_contracts  buy_value_in_Cr  sell_contracts  \
# 0     FINNIFTY FUTURES          277.0            16.38           226.0
# 1    BANKNIFTY FUTURES        40637.0          3124.45         42806.0
# 2   MIDCPNIFTY FUTURES         4182.0           275.01          4684.0
# 3   NIFTYNXT50 FUTURES          381.0            28.68           378.0
# 4        NIFTY FUTURES       133370.0          8392.61         96898.0
# 6        INDEX OPTIONS     46813278.0       3391410.69      47006950.0
# 7        NIFTY OPTIONS     13936352.0        871650.71      13764803.0
# 8     FINNIFTY OPTIONS       450465.0         26550.84        476333.0
# 9    BANKNIFTY OPTIONS     31978252.0       2463778.73      32321188.0
# 10  MIDCPNIFTY OPTIONS       446032.0         29267.26        442017.0
# 11  NIFTYNXT50 OPTIONS         2177.0           163.15          2609.0
# 13       STOCK FUTURES      1144755.0         90778.75       1185257.0
# ...

# %%
derivatives.fno_bhav_copy('28-08-2024')
# Out:
#            TradDt       BizDt Sgmt  Src FinInstrmTp  FinInstrmId  ISIN  \
# 0      2024-08-28  2024-08-28   FO  NSE         STO       151201   NaN
# 1      2024-08-28  2024-08-28   FO  NSE         STO        96220   NaN
# 2      2024-08-28  2024-08-28   FO  NSE         STO        96205   NaN
# 3      2024-08-28  2024-08-28   FO  NSE         STO       133783   NaN
# 4      2024-08-28  2024-08-28   FO  NSE         STO       133782   NaN
# ...           ...         ...  ...  ...         ...          ...   ...
# 37541  2024-08-28  2024-08-28   FO  NSE         STO       101880   NaN
# 37542  2024-08-28  2024-08-28   FO  NSE         STO        89341   NaN
# 37543  2024-08-28  2024-08-28   FO  NSE         STO        72070   NaN
# 37544  2024-08-28  2024-08-28   FO  NSE         STO       149327   NaN
# 37545  2024-08-28  2024-08-28   FO  NSE         STO        72376   NaN
#
#          TckrSymb  SctySrs      XpryDt  ... TtlTradgVol     TtlTrfVal  \
# ...

# %%
derivatives.future_price_volume_data('SBIN','FUTSTK', period='1M')
# Out:
#       TIMESTAMP INSTRUMENT SYMBOL    EXPIRY_DT STRIKE_PRICE OPTION_TYPE  \
# 0   28-Aug-2024     FUTSTK   SBIN  26-Sep-2024         0.00          XX
# 1   28-Aug-2024     FUTSTK   SBIN  29-Aug-2024         0.00          XX
# 2   28-Aug-2024     FUTSTK   SBIN  31-Oct-2024         0.00          XX
# 3   27-Aug-2024     FUTSTK   SBIN  26-Sep-2024         0.00          XX
# 4   27-Aug-2024     FUTSTK   SBIN  29-Aug-2024         0.00          XX
# ..          ...        ...    ...          ...          ...         ...
# 61  30-Jul-2024     FUTSTK   SBIN  29-Aug-2024         0.00          XX
# 62  30-Jul-2024     FUTSTK   SBIN  31-Oct-2024         0.00          XX
# 63  29-Jul-2024     FUTSTK   SBIN  26-Sep-2024         0.00          XX
# 64  29-Jul-2024     FUTSTK   SBIN  29-Aug-2024         0.00          XX
# 65  29-Jul-2024     FUTSTK   SBIN  31-Oct-2024         0.00          XX
#
#    MARKET_TYPE OPENING_PRICE TRADE_HIGH_PRICE TRADE_LOW_PRICE CLOSING_PRICE  \
# ...

# %%
derivatives.nse_live_option_chain('BANKNIFTY', expiry_date='29-08-2024')
# Out:
# Empty DataFrame
# Columns: [Fetch_Time, Symbol, Expiry_Date, CALLS_OI, CALLS_Chng_in_OI, CALLS_Volume, CALLS_IV, CALLS_LTP, CALLS_Net_Chng, CALLS_Bid_Qty, CALLS_Bid_Price, CALLS_Ask_Price, CALLS_Ask_Qty, Strike_Price, PUTS_Bid_Qty, PUTS_Bid_Price, PUTS_Ask_Price, PUTS_Ask_Qty, PUTS_Net_Chng, PUTS_LTP, PUTS_IV, PUTS_Volume, PUTS_Chng_in_OI, PUTS_OI]
# Index: []
#
# [0 rows x 24 columns]

# %%
derivatives.option_price_volume_data('BANKNIFTY','OPTIDX',period='1M')
# Out:
#          TIMESTAMP INSTRUMENT     SYMBOL    EXPIRY_DT STRIKE_PRICE  \
# 0      28-Aug-2024     OPTIDX  BANKNIFTY  01-Oct-2024     43000.00
# 1      28-Aug-2024     OPTIDX  BANKNIFTY  01-Oct-2024     43500.00
# 2      28-Aug-2024     OPTIDX  BANKNIFTY  01-Oct-2024     44000.00
# 3      28-Aug-2024     OPTIDX  BANKNIFTY  01-Oct-2024     44500.00
# 4      28-Aug-2024     OPTIDX  BANKNIFTY  01-Oct-2024     45000.00
# ...            ...        ...        ...          ...          ...
# 34429  29-Jul-2024     OPTIDX  BANKNIFTY  31-Jul-2024     58500.00
# 34430  29-Jul-2024     OPTIDX  BANKNIFTY  31-Jul-2024     59000.00
# 34431  29-Jul-2024     OPTIDX  BANKNIFTY  31-Jul-2024     59500.00
# 34432  29-Jul-2024     OPTIDX  BANKNIFTY  31-Jul-2024     60000.00
# 34433  29-Jul-2024     OPTIDX  BANKNIFTY  31-Jul-2024     60500.00
#
#       OPTION_TYPE MARKET_TYPE OPENING_PRICE TRADE_HIGH_PRICE TRADE_LOW_PRICE  \
# 0              PE           N          0.00             0.00            0.00
# ...

# %%
derivatives.participant_wise_open_interest('28-08-2024')
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             305943              353851            2304816
# 1         DII              85564              144042             211216
# 2         FII             358331              224165            2474521
# 3         Pro              64737               92517             691547
#
#    Future Stock Short  Option Index Call Long  Option Index Put Long  \
# 0              322984                 5915144                6053531
# 1             3191447                    2078                 436634
# 2             1787583                 1397162                2066482
# 3              380086                 1872429                1855670
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# 0                  6309708                 6908486                 1905909
# 1                        0                       0                     458
# ...

# %%
derivatives.participant_wise_trading_volume('28-8-2024')
# Out:
#   Client Type  Future Index Long  Future Index Short  Future Stock Long  \
# 0      Client             302673              327356             927500
# 1         DII              60101               55799             782381
# 2         FII             178847              144992            1144755
# 3         Pro             169618              183092             899088
#
#    Future Stock Short  Option Index Call Long  Option Index Put Long  \
# 0              887392               124159093              107371982
# 1              774912                       0                  30264
# 2             1185257                25046893               21766385
# 3              906163               244288816              212239941
#
#    Option Index Call Short  Option Index Put Short  Option Stock Call Long  \
# 0                124158608               107381989                 1917606
# 1                        0                   47000                   13356
# ...
